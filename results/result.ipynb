# %% [markdown]
# ### A2C

# %%
# read .npy files
import numpy as np
import matplotlib.pyplot as plt

# load training results
train_rewards_42 = np.load('a2c/AAPL/42/train_rewards.npy')
train_rewards_123 = np.load('a2c/AAPL/55/train_rewards.npy')
train_rewards_456 = np.load('a2c/AAPL/457/train_rewards.npy')
plt.plot(train_rewards_42, label='seed 42')
plt.plot(train_rewards_123, label='seed 55')
plt.plot(train_rewards_456, label='seed 457')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for AAPL')
plt.show()

# %%
# read .npy files
import numpy as np
import matplotlib.pyplot as plt

# load training results
train_rewards_42 = np.load('a2c/GOOG/42/train_rewards.npy')
train_rewards_123 = np.load('a2c/GOOG/55/train_rewards.npy')
train_rewards_456 = np.load('a2c/GOOG/457/train_rewards.npy')
plt.plot(train_rewards_42, label='seed 42')
plt.plot(train_rewards_123, label='seed 55')
plt.plot(train_rewards_456, label='seed 457')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for GOOG')
plt.show()

# %%
# read .npy files
import numpy as np
import matplotlib.pyplot as plt

# load training results
train_rewards_42 = np.load('a2c/MSFT/42/train_rewards.npy')
train_rewards_123 = np.load('a2c/MSFT/55/train_rewards.npy')
train_rewards_456 = np.load('a2c/MSFT/457/train_rewards.npy')
plt.plot(train_rewards_42, label='seed 42')
plt.plot(train_rewards_123, label='seed 55')
plt.plot(train_rewards_456, label='seed 457')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for MSFT')
plt.show()

# %% [markdown]
# ### DQN

# %%
# read .npy files
import numpy as np
import matplotlib.pyplot as plt

# load training results
train_rewards_42 = np.load('dqn/AAPL/42/train_rewards.npy')
train_rewards_123 = np.load('dqn/AAPL/55/train_rewards.npy')
train_rewards_456 = np.load('dqn/AAPL/457/train_rewards.npy')
plt.plot(train_rewards_42, label='seed 42')
plt.plot(train_rewards_123, label='seed 55')
plt.plot(train_rewards_456, label='seed 457')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for AAPL')
plt.show()

# %%
# read .npy files
import numpy as np
import matplotlib.pyplot as plt

# load training results
train_rewards_42 = np.load('dqn/GOOG/42/train_rewards.npy')
train_rewards_123 = np.load('dqn/GOOG/55/train_rewards.npy')
train_rewards_456 = np.load('dqn/GOOG/457/train_rewards.npy')
plt.plot(train_rewards_42, label='seed 42')
plt.plot(train_rewards_123, label='seed 55')
plt.plot(train_rewards_456, label='seed 457')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for GOOG')
plt.show()

# %%
# read .npy files
import numpy as np
import matplotlib.pyplot as plt

# load training results
train_rewards_42 = np.load('dqn/MSFT/42/train_rewards.npy')
train_rewards_123 = np.load('dqn/MSFT/55/train_rewards.npy')
train_rewards_456 = np.load('dqn/MSFT/457/train_rewards.npy')
plt.plot(train_rewards_42, label='seed 42')
plt.plot(train_rewards_123, label='seed 55')
plt.plot(train_rewards_456, label='seed 457')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for MSFT')
plt.show()

# %% [markdown]
# ### DDPG

# %%
# read .npy files
import numpy as np
import matplotlib.pyplot as plt

# load training results
train_rewards_42 = np.load('ddpg/AAPL/42/train_rewards.npy')
train_rewards_123 = np.load('ddpg/AAPL/55/train_rewards.npy')
train_rewards_456 = np.load('ddpg/AAPL/457/train_rewards.npy')
plt.plot(train_rewards_42, label='seed 42')
plt.plot(train_rewards_123, label='seed 55')
plt.plot(train_rewards_456, label='seed 457')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for AAPL')
plt.show()

# %%
# read .npy files
import numpy as np
import matplotlib.pyplot as plt

# load training results
train_rewards_42 = np.load('dqn/GOOG/42/train_rewards.npy')
train_rewards_123 = np.load('dqn/GOOG/55/train_rewards.npy')
train_rewards_456 = np.load('dqn/GOOG/457/train_rewards.npy')
plt.plot(train_rewards_42, label='seed 42')
plt.plot(train_rewards_123, label='seed 55')
plt.plot(train_rewards_456, label='seed 457')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for GOOG')
plt.show()

# %%
# read .npy files
import numpy as np
import matplotlib.pyplot as plt

# load training results
train_rewards_42 = np.load('dqn/MSFT/42/train_rewards.npy')
train_rewards_123 = np.load('dqn/MSFT/55/train_rewards.npy')
train_rewards_456 = np.load('dqn/MSFT/457/train_rewards.npy')
plt.plot(train_rewards_42, label='seed 42')
plt.plot(train_rewards_123, label='seed 55')
plt.plot(train_rewards_456, label='seed 457')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for MSFT')
plt.show()

# %% [markdown]
# ## Compare the training rewards of the three models

# %%
# Compare the training rewards of the three models
import numpy as np
import matplotlib

# load training results
train_rewards_a2c = np.load('a2c/AAPL/42/train_rewards.npy')
train_rewards_dqn = np.load('dqn/AAPL/42/train_rewards.npy')
train_rewards_ddpg = np.load('ddpg/AAPL/42/train_rewards.npy')
plt.plot(train_rewards_a2c, label='A2C')
plt.plot(train_rewards_dqn, label='DQN')
plt.plot(train_rewards_ddpg, label='DDPG')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for AAPL')
plt.show()

# %%
# Compare the training rewards of the three models
import numpy as np
import matplotlib

# load training results
train_rewards_a2c = np.load('a2c/GOOG/457/train_rewards.npy')
train_rewards_dqn = np.load('dqn/GOOG/457/train_rewards.npy')
train_rewards_ddpg = np.load('ddpg/GOOG/457/train_rewards.npy')
plt.plot(train_rewards_a2c, label='A2C')
plt.plot(train_rewards_dqn, label='DQN')
plt.plot(train_rewards_ddpg, label='DDPG')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for GOOG')
plt.show()

# %%
# Compare the training rewards of the three models
import numpy as np
import matplotlib

# load training results
train_rewards_a2c = np.load('a2c/MSFT/42/train_rewards.npy')
train_rewards_dqn = np.load('dqn/MSFT/42/train_rewards.npy')
train_rewards_ddpg = np.load('ddpg/MSFT/42/train_rewards.npy')
plt.plot(train_rewards_a2c, label='A2C')
plt.plot(train_rewards_dqn, label='DQN')
plt.plot(train_rewards_ddpg, label='DDPG')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training Reward')
plt.title('Training Reward over 50 Epochs for MSFT')
plt.show()
